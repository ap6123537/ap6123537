# %% [markdown]
# # Multiple Linear Regression-Toyota_Corolla_Price

# %% [markdown]
# ### Consider only the below columns and prepare a prediction model for predicting Price. Corolla<-Corolla[c("Price","Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight")]

# %% [markdown]
# #### Features

# %% [markdown]
# #### Model -- model of the car
# #### Price  -- Offer Price in EUROs
# #### Age_08_04 -- Age in months as in August 2004
# #### Mfg_Month -- Manufacturing month (1-12)
# #### Mfg_Year	-- Manufacturing Year
# #### KM -- Accumulated Kilometers on odometer
# #### Fuel_Type	 -- Fuel Type (Petrol, Diesel, CNG)
# #### HP -- Horse Power
# #### Met_Color	 -- Metallic Color?  (Yes=1, No=0)
# #### Color -- Color (Blue, Red, Grey, Silver, Black, etc.)
# #### Automatic	-- Automatic ( (Yes=1, No=0)
# #### cc -- Cylinder Volume in cubic centimeters
# #### Doors -- Number of doors
# #### Cylinders	-- Number of cylinders
# #### Gears -- Number of gear positions
# #### Quarterly_Tax -- Quarterly road tax in EUROs
# #### Weight -- Weight in Kilograms
# #### Mfr_Guarantee -- Within Manufacturer's Guarantee period  (Yes=1, No=0)
# #### BOVAG_Guarantee -- BOVAG (Dutch dealer network) Guarantee  (Yes=1, No=0)
# #### Guarantee_Period -- 	Guarantee period in months
# #### ABS -- Anti-Lock Brake System (Yes=1, No=0)
# #### Airbag_1 -- Driver_Airbag  (Yes=1, No=0)
# #### Airbag_2 -- Passenger Airbag  (Yes=1, No=0)
# #### Airco -- Airconditioning  (Yes=1, No=0)
# #### Automatic_airco -- Automatic Airconditioning  (Yes=1, No=0)
# #### Boardcomputer -- Boardcomputer  (Yes=1, No=0)
# #### CD_Player -- CD Player  (Yes=1, No=0)
# #### Central_Lock -- Central Lock  (Yes=1, No=0)
# #### Powered_Windows -- Powered Windows  (Yes=1, No=0)
# #### Power_Steering -- Power Steering  (Yes=1, No=0)
# #### Radio -- Radio  (Yes=1, No=0)
# #### Mistlamps	-- Mistlamps  (Yes=1, No=0)
# #### Sport_Model -- Sport Model  (Yes=1, No=0)
# #### Backseat_Divider -- Backseat Divider  (Yes=1, No=0)
# #### Metallic_Rim --Metallic Rim  (Yes=1, No=0)
# #### Radio_cassette -- Radio Cassette  (Yes=1, No=0)
# #### Tow_Bar -- Tow Bar  (Yes=1, No=0)

# %% [markdown]
# # Step -1] Import Libraries

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import warnings as warnings
warnings.filterwarnings("ignore")
from scipy import stats
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.graphics.regressionplots import influence_plot

# %% [markdown]
# # Step-2] Descriptive Analysis

# %% [markdown]
# # Step-2.1] Working with Dataset

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-d0233fcd-aa6e-428f-a8eb-253d70e30b2e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d0233fcd-aa6e-428f-a8eb-253d70e30b2e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
ToyotaCorolla = pd.read_csv("ToyotaCorolla.csv",encoding='latin1')

# %% [markdown]
# #### Exploring the dataset

# %%
# Displaying first ten records
ToyotaCorolla.head(10)
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
# 5   6     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  12950         32
# 6   7   TOYOTA Corolla 2.0 D4D 90 3DR TERRA 2/3-Doors  16900         27
# 7   8   TOYOTA Corolla 2.0 D4D 90 3DR TERRA 2/3-Doors  18600         30
# 8   9     TOYOTA Corolla 1800 T SPORT VVT I 2/3-Doors  21500         27
# 9  10     TOYOTA Corolla 1.9 D HATCHB TERRA 2/3-Doors  12950         23
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  ... Central_Lock  \
# 0         10      2002  46986    Diesel   90          1  ...            1
# ...

# %%
# Shape of the data
ToyotaCorolla.shape
# Out:
# (1436, 38)

# %%
# Summary of the data
ToyotaCorolla.describe()
# Out:
#                 Id         Price    Age_08_04    Mfg_Month     Mfg_Year  \
# count  1436.000000   1436.000000  1436.000000  1436.000000  1436.000000
# mean    721.555014  10730.824513    55.947075     5.548747  1999.625348
# std     416.476890   3626.964585    18.599988     3.354085     1.540722
# min       1.000000   4350.000000     1.000000     1.000000  1998.000000
# 25%     361.750000   8450.000000    44.000000     3.000000  1998.000000
# 50%     721.500000   9900.000000    61.000000     5.000000  1999.000000
# 75%    1081.250000  11950.000000    70.000000     8.000000  2001.000000
# max    1442.000000  32500.000000    80.000000    12.000000  2004.000000
#
#                   KM           HP    Met_Color    Automatic           cc  ...  \
# count    1436.000000  1436.000000  1436.000000  1436.000000   1436.00000  ...
# mean    68533.259749   101.502089     0.674791     0.055710   1576.85585  ...
# std     37506.448872    14.981080     0.468616     0.229441    424.38677  ...
# ...

# %%
# Check the data types
ToyotaCorolla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 38 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1436 non-null   int64
#  1   Model             1436 non-null   object
#  2   Price             1436 non-null   int64
#  3   Age_08_04         1436 non-null   int64
#  4   Mfg_Month         1436 non-null   int64
#  5   Mfg_Year          1436 non-null   int64
#  6   KM                1436 non-null   int64
#  7   Fuel_Type         1436 non-null   object
#  8   HP                1436 non-null   int64
#  9   Met_Color         1436 non-null   int64
#  10  Color             1436 non-null   object
#  11  Automatic         1436 non-null   int64
#  12  cc                1436 non-null   int64
#  13  Doors             1436 non-null   int64
#  14  Cylinders         1436 non-null   int64
#  15  Gears             1436 non-null   int64
# ...

# %% [markdown]
# #### Modifying the dataset

# %%
 ToyotaCorolla = ToyotaCorolla[["Price","Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight"]]
ToyotaCorolla.head(10)
# Out:
#    Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0  13500         23  46986   90  2000      3      5            210    1165
# 1  13750         23  72937   90  2000      3      5            210    1165
# 2  13950         24  41711   90  2000      3      5            210    1165
# 3  14950         26  48000   90  2000      3      5            210    1165
# 4  13750         30  38500   90  2000      3      5            210    1170
# 5  12950         32  61000   90  2000      3      5            210    1170
# 6  16900         27  94612   90  2000      3      5            210    1245
# 7  18600         30  75889   90  2000      3      5            210    1245
# 8  21500         27  19700  192  1800      3      5            100    1185
# 9  12950         23  71138   69  1900      3      5            185    1105

# %%
ToyotaCorolla = ToyotaCorolla.rename(columns={"Age_08_04":"Age_mns","KM":"Run_KM","cc":"CC",
                                "Doors":"No_Doors","Gears":"No_Gears","Quarterly_Tax":"Qtrly_Tax","Weight":"Wt_Kgs"})
ToyotaCorolla
# Out:
#       Price  Age_mns  Run_KM   HP    CC  No_Doors  No_Gears  Qtrly_Tax  Wt_Kgs
# 0     13500       23   46986   90  2000         3         5        210    1165
# 1     13750       23   72937   90  2000         3         5        210    1165
# 2     13950       24   41711   90  2000         3         5        210    1165
# 3     14950       26   48000   90  2000         3         5        210    1165
# 4     13750       30   38500   90  2000         3         5        210    1170
# ...     ...      ...     ...  ...   ...       ...       ...        ...     ...
# 1431   7500       69   20544   86  1300         3         5         69    1025
# 1432  10845       72   19000   86  1300         3         5         69    1015
# 1433   8500       71   17016   86  1300         3         5         69    1015
# 1434   7250       70   16916   86  1300         3         5         69    1015
# 1435   6950       76       1  110  1600         5         5         19    1114
#
# [1436 rows x 9 columns]

# %% [markdown]
# ### Step-2.2 : Handling missing values

# %%
# Check for Null values
ToyotaCorolla.isnull().sum()
# Out:
# Price        0
# Age_mns      0
# Run_KM       0
# HP           0
# CC           0
# No_Doors     0
# No_Gears     0
# Qtrly_Tax    0
# Wt_Kgs       0
# dtype: int64

# %%
# Check for duplicate values
ToyotaCorolla[ToyotaCorolla.duplicated()].shape
# Out:
# (1, 9)

# %%
ToyotaCorolla[ToyotaCorolla.duplicated()]
# Out:
#      Price  Age_mns  Run_KM   HP    CC  No_Doors  No_Gears  Qtrly_Tax  Wt_Kgs
# 113  24950        8   13253  116  2000         5         5        234    1320

# %%
# As there is a duplicate observation, remove it from the dataset
ToyotaCorolla =ToyotaCorolla.drop_duplicates()

# %%
ToyotaCorolla.reset_index(inplace=True,drop=True)
ToyotaCorolla
# Out:
#       Price  Age_mns  Run_KM   HP    CC  No_Doors  No_Gears  Qtrly_Tax  Wt_Kgs
# 0     13500       23   46986   90  2000         3         5        210    1165
# 1     13750       23   72937   90  2000         3         5        210    1165
# 2     13950       24   41711   90  2000         3         5        210    1165
# 3     14950       26   48000   90  2000         3         5        210    1165
# 4     13750       30   38500   90  2000         3         5        210    1170
# ...     ...      ...     ...  ...   ...       ...       ...        ...     ...
# 1430   7500       69   20544   86  1300         3         5         69    1025
# 1431  10845       72   19000   86  1300         3         5         69    1015
# 1432   8500       71   17016   86  1300         3         5         69    1015
# 1433   7250       70   16916   86  1300         3         5         69    1015
# 1434   6950       76       1  110  1600         5         5         19    1114
#
# [1435 rows x 9 columns]

# %% [markdown]
# # Step -2.3] Exploring data using Visualisation

# %% [markdown]
# #### Differentiate Discrete and Continuous features

# %%
x=[]
for feature in ToyotaCorolla.columns:
    if len(ToyotaCorolla[feature].unique())<20:
        x.append(feature)
dis = pd.DataFrame(x,columns=["Discrete features"])

# %%
y=[]
for feature in ToyotaCorolla.columns:
    if len(ToyotaCorolla[feature].unique())>20:
        y.append(feature)
cont = pd.DataFrame(y,columns=["Continuous features"])

# %%
dis_cont = pd.concat([dis,cont],axis=1)
dis_cont
# Out:
#   Discrete features Continuous features
# 0                HP               Price
# 1                CC             Age_mns
# 2          No_Doors              Run_KM
# 3          No_Gears              Wt_Kgs
# 4         Qtrly_Tax                 NaN

# %%
ToyotaCorolla_dis=ToyotaCorolla[x]
ToyotaCorolla_dis
# Out:
#        HP    CC  No_Doors  No_Gears  Qtrly_Tax
# 0      90  2000         3         5        210
# 1      90  2000         3         5        210
# 2      90  2000         3         5        210
# 3      90  2000         3         5        210
# 4      90  2000         3         5        210
# ...   ...   ...       ...       ...        ...
# 1430   86  1300         3         5         69
# 1431   86  1300         3         5         69
# 1432   86  1300         3         5         69
# 1433   86  1300         3         5         69
# 1434  110  1600         5         5         19
#
# [1435 rows x 5 columns]

# %%
ToyotaCorolla_cont=ToyotaCorolla[y]
ToyotaCorolla_cont
# Out:
#       Price  Age_mns  Run_KM  Wt_Kgs
# 0     13500       23   46986    1165
# 1     13750       23   72937    1165
# 2     13950       24   41711    1165
# 3     14950       26   48000    1165
# 4     13750       30   38500    1170
# ...     ...      ...     ...     ...
# 1430   7500       69   20544    1025
# 1431  10845       72   19000    1015
# 1432   8500       71   17016    1015
# 1433   7250       70   16916    1015
# 1434   6950       76       1    1114
#
# [1435 rows x 4 columns]

# %% [markdown]
# #### Visualizing continuous features

# %% [markdown]
# #### Histogram

# %%
plt.subplots(figsize = (12,10))
plt.subplot(2,2,1)
plt.hist(ToyotaCorolla['Price'])
plt.title('Price in Euros')
plt.subplot(2,2,2)
plt.hist(ToyotaCorolla['Age_mns'])
plt.title('Age in months')
plt.subplot(2,2,3)
plt.hist(ToyotaCorolla['Run_KM'])
plt.title('Run in Kilometers')
plt.subplot(2,2,4)
plt.hist(ToyotaCorolla['Wt_Kgs'])
plt.title('Weight in Kilograms')
plt.show()

# %% [markdown]
# #### Boxplot

# %%
plt.subplots(figsize = (15,27))
plt.subplot(4,1,1)
sb.boxplot(ToyotaCorolla['Price'])
plt.title('Price in Euros')
plt.subplot(4,1,2)
sb.boxplot(ToyotaCorolla['Age_mns'])
plt.title('Age in months')
plt.subplot(4,1,3)
sb.boxplot(ToyotaCorolla['Run_KM'])
plt.title('Run in Kilometers')
plt.subplot(4,1,4)
sb.boxplot(ToyotaCorolla['Wt_Kgs'])
plt.title('Weight in Kilograms')
plt.show()

# %% [markdown]
# #### We can observe that there are outliers in all the above features. The outliers are to be investigated to get accurate model.

# %% [markdown]
# #### Q-Q plot

# %%
# To check whether the data is following normal distribution
sm.qqplot(ToyotaCorolla['Price'], line = 'q')
plt.title('Price in Euros')
sm.qqplot(ToyotaCorolla['Age_mns'], line = 'q')
plt.title('Age in months')
sm.qqplot(ToyotaCorolla['Run_KM'], line = 'q')
plt.title('Run in Kilometers')
sm.qqplot(ToyotaCorolla['Wt_Kgs'], line = 'q')
plt.title('Weight in Kilograms')
plt.show()

# %% [markdown]
# #### Correlation and Heat map

# %%
# Checking for Correlation between variables
ToyotaCorolla_cont.corr()
# Out:
#             Price   Age_mns    Run_KM    Wt_Kgs
# Price    1.000000 -0.876273 -0.569420  0.575869
# Age_mns -0.876273  1.000000  0.504575 -0.466484
# Run_KM  -0.569420  0.504575  1.000000 -0.023969
# Wt_Kgs   0.575869 -0.466484 -0.023969  1.000000

# %%
sb.heatmap(ToyotaCorolla_cont.corr(),annot=True)
plt.show()

# %% [markdown]
# #### We can observe that the Price is strongly related with Age. The Price are moderately related with Weight and Run features .

# %%
plt.subplots(figsize = (14,12))
plt.subplot(2,2,1)
sb.regplot(x=ToyotaCorolla_cont['Age_mns'],y=ToyotaCorolla['Price'])
plt.title('Age vs Price')
plt.subplot(2,2,2)
sb.regplot(x=ToyotaCorolla_cont['Run_KM'],y=ToyotaCorolla['Price'])
plt.title('Run vs Price')
plt.subplot(2,2,3)
sb.regplot(x=ToyotaCorolla_cont['Wt_Kgs'],y=ToyotaCorolla['Price'])
plt.title('Weight vs Price')
plt.show()

# %% [markdown]
# #### Pair plot

# %%
sb.set_style(style='darkgrid')
sb.pairplot(ToyotaCorolla_cont)
plt.show()

# %% [markdown]
# #### Visualizing discrete features

# %%
for i in ToyotaCorolla_dis.columns:
    plt.figure()
    sb.barplot(data=ToyotaCorolla,x=i,y='Price')
plt.show()

# %% [markdown]
# #### Correlation and Heat map

# %%
# Checking for Correlation between variables
co_rel = pd.concat([ToyotaCorolla_dis,ToyotaCorolla['Price']],axis=1)
co_rel
co_rel.corr()
# Out:
#                  HP        CC  No_Doors  No_Gears  Qtrly_Tax     Price
# HP         1.000000  0.035207  0.091803  0.209642  -0.302287  0.314134
# CC         0.035207  1.000000  0.079254  0.014732   0.305982  0.124375
# No_Doors   0.091803  0.079254  1.000000 -0.160101   0.107353  0.183604
# No_Gears   0.209642  0.014732 -0.160101  1.000000  -0.005125  0.063831
# Qtrly_Tax -0.302287  0.305982  0.107353 -0.005125   1.000000  0.211508
# Price      0.314134  0.124375  0.183604  0.063831   0.211508  1.000000

# %%
sb.heatmap(co_rel.corr(),annot=True)
plt.show()

# %% [markdown]
# #### We can clearly see that there is very weak correlation between Price and other variables, as the correlation values are <0.5.
# #### Hence consider only continuous variables in our model.

# %% [markdown]
# # Step -3] Build a Multiple Linear Regeression model

# %% [markdown]
# # Step -3.1] Fitting the model considering Raw data

# %%
# The Multiple Linear regression equation is Price=βo+β1(Age)+β2(Run)+β3(Weight).
# Using the following code we build a Multiple linear regression model, which predicts the price for given parameters
model=smf.ols("Price~Age_mns+Run_KM+Wt_Kgs",data=ToyotaCorolla_cont).fit()

# %% [markdown]
# #### Printing Estimated Parameters

# %%
# We get values of βo,β1,β2,β3
model.params
# Out:
# Intercept   -1722.709518
# Age_mns      -120.268560
# Run_KM         -0.024114
# Wt_Kgs         19.425617
# dtype: float64

# %% [markdown]
# # Step -4] Model Diagnostics

# %% [markdown]
# #### Residuals

# %%
# Residuals or errors of the model for each observation. Error = Actual value - Predicted value
model.resid
# Out:
# 0      -3508.950179
# 1      -2633.174959
# 2      -3065.881507
# 3      -1673.693184
# 4      -2718.827396
#            ...
# 1430   -1894.625074
# 1431    1968.205190
# 1432    -544.904996
# 1433   -1917.584929
# 1434   -3826.993285
# Length: 1435, dtype: float64

# %%
# Standardised residuals
model.resid_pearson
# Out:
# array([-2.48115129, -1.86189746, -2.16786089, ..., -0.38529807,
#        -1.35590934, -2.70603709])

# %% [markdown]
# #### Predicted values

# %%
pred=model.predict(ToyotaCorolla)
pred
# Out:
# 0       17008.950179
# 1       16383.174959
# 2       17015.881507
# 3       16623.693184
# 4       16468.827396
#             ...
# 1430     9394.625074
# 1431     8876.794810
# 1432     9044.904996
# 1433     9167.584929
# 1434    10776.993285
# Length: 1435, dtype: float64

# %% [markdown]
# #### Overall Summary

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.847
# Model:                            OLS   Adj. R-squared:                  0.846
# Method:                 Least Squares   F-statistic:                     2635.
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):               0.00
# Time:                        15:34:24   Log-Likelihood:                -12444.
# No. Observations:                1435   AIC:                         2.490e+04
# Df Residuals:                    1431   BIC:                         2.492e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1722.7095    967.073     -1.781      0.075   -3619.743     174.324
# ...

# %% [markdown]
# #### Root Mean Square Error(RMSE)

# %%
rmse = np.sqrt(model.mse_resid)
rmse
# Out:
# 1414.242733320169

# %% [markdown]
# #### From the Summary, we can see that the R² value is good and the Root Mean Square Error value is low.
# #### As the pvalues for independent features are less than 0.05. They seem to be significant.

# %% [markdown]
# # Step -5] Treating the Outlier

# %% [markdown]
# #### In the boxplot, we observed that there are outliers. The same are to be detected now.

# %% [markdown]
# # Step -5.1] Detecting the outlier

# %% [markdown]
# #### Using Interquartile range method

# %% [markdown]
# #### Price feature

# %%
Q1 = np.quantile(ToyotaCorolla_cont.Price,0.25)
Q3 = np.quantile(ToyotaCorolla_cont.Price,0.75)
IQR = Q3 - Q1
upper_fence = Q3+(1.5*IQR)
lower_fence = Q1-(1.5*IQR)
print('First Quartile=', Q1,'\n' 'Third Quartile=', Q3,'\n'
      'Inter-Quartile Range=', IQR,'\n' 'Upper fence =', upper_fence,'\n' 'Lower fence=', lower_fence)
# Out:
# First Quartile= 8450.0
# Third Quartile= 11950.0
# Inter-Quartile Range= 3500.0
# Upper fence = 17200.0
# Lower fence= 3200.0

# %%
ToyotaCorolla_cont[(ToyotaCorolla_cont.Price <= lower_fence) | (ToyotaCorolla_cont.Price >= upper_fence)]
# Out:
#      Price  Age_mns  Run_KM  Wt_Kgs
# 7    18600       30   75889    1245
# 8    21500       27   19700    1185
# 10   20950       25   31461    1185
# 11   19950       22   43610    1185
# 12   19600       25   32189    1185
# ..     ...      ...     ...     ...
# 181  21125        2     225    1110
# 182  21500        2      15    1130
# 183  17795        1       1    1100
# 184  18245        1       1    1075
# 522  18950       49   49568    1105
#
# [110 rows x 4 columns]

# %% [markdown]
# #### Hence we can see that there are outliers in the Price feature and shall be treated.

# %% [markdown]
# #### Age feature

# %%
Q1 = np.quantile(ToyotaCorolla_cont.Age_mns,0.25)
Q3 = np.quantile(ToyotaCorolla_cont.Age_mns,0.75)
IQR = Q3 - Q1
upper_fence = Q3+(1.5*IQR)
lower_fence = Q1-(1.5*IQR)
print('First Quartile=', Q1,'\n' 'Third Quartile=', Q3,'\n'
      'Inter-Quartile Range=', IQR,'\n' 'Upper fence =', upper_fence,'\n' 'Lower fence=', lower_fence)
# Out:
# First Quartile= 44.0
# Third Quartile= 70.0
# Inter-Quartile Range= 26.0
# Upper fence = 109.0
# Lower fence= 5.0

# %%
ToyotaCorolla_cont[(ToyotaCorolla_cont.Age_mns <= lower_fence) | (ToyotaCorolla_cont.Age_mns >= upper_fence)]
# Out:
#      Price  Age_mns  Run_KM  Wt_Kgs
# 109  32500        4       1    1480
# 110  31000        4    4000    1480
# 111  31275        4    1500    1480
# 181  21125        2     225    1110
# 182  21500        2      15    1130
# 183  17795        1       1    1100
# 184  18245        1       1    1075

# %% [markdown]
# #### Hence we can see that there are outliers in the Age feature and shall be treated.

# %% [markdown]
# #### Run feature

# %%
Q1 = np.quantile(ToyotaCorolla_cont.Run_KM,0.25)
Q3 = np.quantile(ToyotaCorolla_cont.Run_KM,0.75)
IQR = Q3 - Q1
upper_fence = Q3+(1.5*IQR)
lower_fence = Q1-(1.5*IQR)
print('First Quartile=', Q1,'\n' 'Third Quartile=', Q3,'\n'
      'Inter-Quartile Range=', IQR,'\n' 'Upper fence =', upper_fence,'\n' 'Lower fence=', lower_fence)
# Out:
# First Quartile= 43000.0
# Third Quartile= 87041.5
# Inter-Quartile Range= 44041.5
# Upper fence = 153103.75
# Lower fence= -23062.25

# %%
ToyotaCorolla_cont[(ToyotaCorolla_cont.Run_KM <= lower_fence) | (ToyotaCorolla_cont.Run_KM >= upper_fence)]
# Out:
#       Price  Age_mns  Run_KM  Wt_Kgs
# 185    6950       43  243000    1110
# 186    9500       38  180638    1160
# 187   11950       40  179860    1205
# 188    7750       43  178858    1084
# 189   11950       40  161000    1105
# 190    4350       44  158320    1110
# 377    6500       53  216000    1110
# 378    6400       51  198167    1095
# 379    7000       53  176000    1105
# 380    7750       54  174139    1100
# 381    8900       45  174000    1095
# 602    6950       58  205000    1100
# 603    7900       68  204250    1115
# 604    5950       68  194545    1000
# 605    7500       59  190900    1115
# 606    7500       62  183500    1140
# 607    6900       65  176184    1115
# 608    5751       67  174833    1100
# 609    6950       68  155720    1015
# 610    7950       67  155500    1050
# 611    7750       59  154783    1120
# 612    7950       64  154462    1135
# 1043   5900       73  232940    1172
# 1044   6950       79  218118    1150
# ...

# %% [markdown]
# #### Hence we can see that there are outliers in the Run feature and shall be treated.

# %% [markdown]
# #### Weight feature

# %%
Q1 = np.quantile(ToyotaCorolla_cont.Wt_Kgs,0.25)
Q3 = np.quantile(ToyotaCorolla_cont.Wt_Kgs,0.75)
IQR = Q3 - Q1
upper_fence = Q3+(1.5*IQR)
lower_fence = Q1-(1.5*IQR)
print('First Quartile=', Q1,'\n' 'Third Quartile=', Q3,'\n'
      'Inter-Quartile Range=', IQR,'\n' 'Upper fence =', upper_fence,'\n' 'Lower fence=', lower_fence)
# Out:
# First Quartile= 1040.0
# Third Quartile= 1085.0
# Inter-Quartile Range= 45.0
# Upper fence = 1152.5
# Lower fence= 972.5

# %%
ToyotaCorolla_cont[(ToyotaCorolla_cont.Wt_Kgs <= lower_fence) | (ToyotaCorolla_cont.Wt_Kgs >= upper_fence)]
# Out:
#       Price  Age_mns  Run_KM  Wt_Kgs
# 0     13500       23   46986    1165
# 1     13750       23   72937    1165
# 2     13950       24   41711    1165
# 3     14950       26   48000    1165
# 4     13750       30   38500    1170
# ...     ...      ...     ...     ...
# 600    7500       50       1    1260
# 653    6950       65  114383    1260
# 767   10950       59   78750    1155
# 959    9390       66   50806    1480
# 1043   5900       73  232940    1172
#
# [65 rows x 4 columns]

# %% [markdown]
# #### Hence we can see that there are outliers in the Weight feature and shall be treated.

# %% [markdown]
# # Step -5.2] Treating the outlier

# %% [markdown]
# #### a.) Mean Imputation method

# %% [markdown]
# #### Price feature

# %%
# Replace the outlier value with the mean of the column
ToyotaCorolla_cont1 =ToyotaCorolla_cont.copy()
for i in ToyotaCorolla_cont1['Price']:
    Q1 = np.quantile(ToyotaCorolla_cont1.Price,0.25)
    Q3 = np.quantile(ToyotaCorolla_cont1.Price,0.75)
    IQR = Q3 - Q1
    upper_fence = Q3+(1.5*IQR)
    lower_fence = Q1-(1.5*IQR)
    if i > upper_fence or i < lower_fence:
       ToyotaCorolla_cont1['Price']=ToyotaCorolla_cont1['Price'].replace(i,np.mean(ToyotaCorolla_cont1['Price']))
ToyotaCorolla_cont1
# Out:
#              Price  Age_mns  Run_KM  Wt_Kgs
# 0     13500.000000       23   46986    1165
# 1     13750.000000       23   72937    1165
# 2     13950.000000       24   41711    1165
# 3     10238.651011       26   48000    1165
# 4     13750.000000       30   38500    1170
# ...            ...      ...     ...     ...
# 1430   7500.000000       69   20544    1025
# 1431  10845.000000       72   19000    1015
# 1432   8500.000000       71   17016    1015
# 1433   7250.000000       70   16916    1015
# 1434   6950.000000       76       1    1114
#
# [1435 rows x 4 columns]

# %%
# Check for Outlier
plt.boxplot(ToyotaCorolla_cont1['Price'])
plt.show()

# %% [markdown]
# #### Age feature

# %%
# Replace the outlier value with the mean of the column
for i in ToyotaCorolla_cont1['Age_mns']:
    Q1 = np.quantile(ToyotaCorolla_cont1.Age_mns,0.25)
    Q3 = np.quantile(ToyotaCorolla_cont1.Age_mns,0.75)
    IQR = Q3 - Q1
    upper_fence = Q3+(1.5*IQR)
    lower_fence = Q1-(1.5*IQR)
    if i > upper_fence or i < lower_fence:
       ToyotaCorolla_cont1['Age_mns']=ToyotaCorolla_cont1['Age_mns'].replace(i,np.mean(ToyotaCorolla_cont1['Age_mns']))
ToyotaCorolla_cont1
# Out:
#              Price  Age_mns  Run_KM  Wt_Kgs
# 0     13500.000000     23.0   46986    1165
# 1     13750.000000     23.0   72937    1165
# 2     13950.000000     24.0   41711    1165
# 3     10238.651011     26.0   48000    1165
# 4     13750.000000     30.0   38500    1170
# ...            ...      ...     ...     ...
# 1430   7500.000000     69.0   20544    1025
# 1431  10845.000000     72.0   19000    1015
# 1432   8500.000000     71.0   17016    1015
# 1433   7250.000000     70.0   16916    1015
# 1434   6950.000000     76.0       1    1114
#
# [1435 rows x 4 columns]

# %%
# Check for Outlier
plt.boxplot(ToyotaCorolla_cont1['Age_mns'])
plt.show()

# %% [markdown]
# #### Run feature

# %%
# Replace the outlier value with the mean of the column
for i in ToyotaCorolla_cont1['Run_KM']:
    Q1 = np.quantile(ToyotaCorolla_cont1.Run_KM,0.25)
    Q3 = np.quantile(ToyotaCorolla_cont1.Run_KM,0.75)
    IQR = Q3 - Q1
    upper_fence = Q3+(1.5*IQR)
    lower_fence = Q1-(1.5*IQR)
    if i > upper_fence or i < lower_fence:
        ToyotaCorolla_cont1['Run_KM']=ToyotaCorolla_cont1['Run_KM'].replace(i,np.mean(ToyotaCorolla_cont1['Run_KM']))
ToyotaCorolla_cont1
# Out:
#              Price  Age_mns   Run_KM  Wt_Kgs
# 0     13500.000000     23.0  46986.0    1165
# 1     13750.000000     23.0  72937.0    1165
# 2     13950.000000     24.0  41711.0    1165
# 3     10238.651011     26.0  48000.0    1165
# 4     13750.000000     30.0  38500.0    1170
# ...            ...      ...      ...     ...
# 1430   7500.000000     69.0  20544.0    1025
# 1431  10845.000000     72.0  19000.0    1015
# 1432   8500.000000     71.0  17016.0    1015
# 1433   7250.000000     70.0  16916.0    1015
# 1434   6950.000000     76.0      1.0    1114
#
# [1435 rows x 4 columns]

# %%
# Check for Outlier
plt.boxplot(ToyotaCorolla_cont1['Run_KM'])
plt.show()

# %% [markdown]
# #### Weight feature

# %%
# Replace the outlier value with the mean of the column
for i in ToyotaCorolla_cont1['Wt_Kgs']:
    Q1 = np.quantile(ToyotaCorolla_cont1.Wt_Kgs,0.25)
    Q3 = np.quantile(ToyotaCorolla_cont1.Wt_Kgs,0.75)
    IQR = Q3 - Q1
    upper_fence = Q3+(1.5*IQR)
    lower_fence = Q1-(1.5*IQR)
    if i > upper_fence or i < lower_fence:
        ToyotaCorolla_cont1['Wt_Kgs']=ToyotaCorolla_cont1['Wt_Kgs'].replace(i,np.mean(ToyotaCorolla_cont1['Wt_Kgs']))
ToyotaCorolla_cont1
# Out:
#              Price  Age_mns   Run_KM       Wt_Kgs
# 0     13500.000000     23.0  46986.0  1072.287108
# 1     13750.000000     23.0  72937.0  1072.287108
# 2     13950.000000     24.0  41711.0  1072.287108
# 3     10238.651011     26.0  48000.0  1072.287108
# 4     13750.000000     30.0  38500.0  1071.770242
# ...            ...      ...      ...          ...
# 1430   7500.000000     69.0  20544.0  1025.000000
# 1431  10845.000000     72.0  19000.0  1015.000000
# 1432   8500.000000     71.0  17016.0  1015.000000
# 1433   7250.000000     70.0  16916.0  1015.000000
# 1434   6950.000000     76.0      1.0  1114.000000
#
# [1435 rows x 4 columns]

# %%
# Check for Outlier
plt.boxplot(ToyotaCorolla_cont1['Wt_Kgs'])
plt.show()

# %% [markdown]
# #### b.) Median Imputation method

# %% [markdown]
# #### Price feature

# %%
# Replace the outlier value with the median of the column
ToyotaCorolla_cont2 = ToyotaCorolla_cont.copy()
for i in ToyotaCorolla_cont2['Price']:
    Q1 = np.quantile(ToyotaCorolla_cont2.Price,0.25)
    Q3 = np.quantile(ToyotaCorolla_cont2.Price,0.75)
    IQR = Q3 - Q1
    upper_fence = Q3+(1.5*IQR)
    lower_fence = Q1-(1.5*IQR)
    if i > upper_fence or i < lower_fence:
        ToyotaCorolla_cont2['Price']=ToyotaCorolla_cont2['Price'].replace(i,np.median(ToyotaCorolla_cont2['Price']))
ToyotaCorolla_cont2
# Out:
#       Price  Age_mns  Run_KM  Wt_Kgs
# 0     13500       23   46986    1165
# 1     13750       23   72937    1165
# 2     13950       24   41711    1165
# 3      9900       26   48000    1165
# 4     13750       30   38500    1170
# ...     ...      ...     ...     ...
# 1430   7500       69   20544    1025
# 1431  10845       72   19000    1015
# 1432   8500       71   17016    1015
# 1433   7250       70   16916    1015
# 1434   6950       76       1    1114
#
# [1435 rows x 4 columns]

# %%
# Check for Outlier
plt.boxplot(ToyotaCorolla_cont2['Price'])
plt.show()

# %% [markdown]
# #### Age feature

# %%
# Replace the outlier value with the median of the column
for i in ToyotaCorolla_cont2['Age_mns']:
    Q1 = np.quantile(ToyotaCorolla_cont2.Age_mns,0.25)
    Q3 = np.quantile(ToyotaCorolla_cont2.Age_mns,0.75)
    IQR = Q3 - Q1
    upper_fence = Q3+(1.5*IQR)
    lower_fence = Q1-(1.5*IQR)
    if i > upper_fence or i < lower_fence:
        ToyotaCorolla_cont2['Age_mns']= ToyotaCorolla_cont2['Age_mns'].replace(i,np.median(ToyotaCorolla_cont2['Age_mns']))
ToyotaCorolla_cont2
# Out:
#       Price  Age_mns  Run_KM  Wt_Kgs
# 0     13500       23   46986    1165
# 1     13750       23   72937    1165
# 2     13950       24   41711    1165
# 3      9900       26   48000    1165
# 4     13750       30   38500    1170
# ...     ...      ...     ...     ...
# 1430   7500       69   20544    1025
# 1431  10845       72   19000    1015
# 1432   8500       71   17016    1015
# 1433   7250       70   16916    1015
# 1434   6950       76       1    1114
#
# [1435 rows x 4 columns]

# %%
# Check for Outlier
plt.boxplot(ToyotaCorolla_cont2['Age_mns'])
plt.show()

# %% [markdown]
# #### Run feature

# %%
# Replace the outlier value with the median of the column
for i in ToyotaCorolla_cont2['Run_KM']:
    Q1 = np.quantile(ToyotaCorolla_cont2.Run_KM,0.25)
    Q3 = np.quantile(ToyotaCorolla_cont2.Run_KM,0.75)
    IQR = Q3 - Q1
    upper_fence = Q3+(1.5*IQR)
    lower_fence = Q1-(1.5*IQR)
    if i > upper_fence or i < lower_fence:
        ToyotaCorolla_cont2['Run_KM']= ToyotaCorolla_cont2['Run_KM'].replace(i,np.median(ToyotaCorolla_cont2['Run_KM']))
ToyotaCorolla_cont2
# Out:
#       Price  Age_mns  Run_KM  Wt_Kgs
# 0     13500       23   46986    1165
# 1     13750       23   72937    1165
# 2     13950       24   41711    1165
# 3      9900       26   48000    1165
# 4     13750       30   38500    1170
# ...     ...      ...     ...     ...
# 1430   7500       69   20544    1025
# 1431  10845       72   19000    1015
# 1432   8500       71   17016    1015
# 1433   7250       70   16916    1015
# 1434   6950       76       1    1114
#
# [1435 rows x 4 columns]

# %%
# Check for Outlier
plt.boxplot(ToyotaCorolla_cont2['Run_KM'])
plt.show()

# %% [markdown]
# #### Weight feature

# %%
# Replace the outlier value with the median of the column
for i in ToyotaCorolla_cont2['Wt_Kgs']:
    Q1 = np.quantile(ToyotaCorolla_cont2.Wt_Kgs,0.25)
    Q3 = np.quantile(ToyotaCorolla_cont2.Wt_Kgs,0.75)
    IQR = Q3 - Q1
    upper_fence = Q3+(1.5*IQR)
    lower_fence = Q1-(1.5*IQR)
    if i > upper_fence or i < lower_fence:
        ToyotaCorolla_cont2['Wt_Kgs']= ToyotaCorolla_cont2['Wt_Kgs'].replace(i,np.median(ToyotaCorolla_cont2['Wt_Kgs']))
ToyotaCorolla_cont2
# Out:
#       Price  Age_mns  Run_KM  Wt_Kgs
# 0     13500       23   46986    1070
# 1     13750       23   72937    1070
# 2     13950       24   41711    1070
# 3      9900       26   48000    1070
# 4     13750       30   38500    1070
# ...     ...      ...     ...     ...
# 1430   7500       69   20544    1025
# 1431  10845       72   19000    1015
# 1432   8500       71   17016    1015
# 1433   7250       70   16916    1015
# 1434   6950       76       1    1114
#
# [1435 rows x 4 columns]

# %%
# Check for Outlier
plt.boxplot(ToyotaCorolla_cont2['Wt_Kgs'])
plt.show()

# %% [markdown]
# ### c.) Remove the outlier

# %% [markdown]
# #### Price feature

# %%
# Remove entire observation containing the outlier
ToyotaCorolla_cont3 = ToyotaCorolla_cont.copy()
for i in ToyotaCorolla_cont3['Price']:
    Q1 = np.quantile(ToyotaCorolla_cont3.Price,0.25)
    Q3 = np.quantile(ToyotaCorolla_cont3.Price,0.75)
    IQR = Q3 - Q1
    upper_fence = Q3+(1.5*IQR)
    lower_fence = Q1-(1.5*IQR)
    if i > upper_fence or i < lower_fence:
        ToyotaCorolla_cont3.drop(ToyotaCorolla_cont3[ToyotaCorolla_cont3['Price']==i].index,inplace=True)
ToyotaCorolla_cont3.shape
# Out:
# (1282, 4)

# %%
# Check for Outlier
plt.boxplot(ToyotaCorolla_cont3['Price'])
plt.show()

# %% [markdown]
# #### Age feature

# %%
# Remove entire observation containing the outlier
for i in ToyotaCorolla_cont3['Age_mns']:
    Q1 = np.quantile(ToyotaCorolla_cont3.Age_mns,0.25)
    Q3 = np.quantile(ToyotaCorolla_cont3.Age_mns,0.75)
    IQR = Q3 - Q1
    upper_fence = Q3+(1.5*IQR)
    lower_fence = Q1-(1.5*IQR)
    if i > upper_fence or i < lower_fence:
        ToyotaCorolla_cont3.drop(ToyotaCorolla_cont3[ToyotaCorolla_cont3['Age_mns']==i].index,inplace=True)
ToyotaCorolla_cont3.shape
# Out:
# (1282, 4)

# %%
# Check for Outlier
plt.boxplot(ToyotaCorolla_cont3['Age_mns'])
plt.show()

# %% [markdown]
# #### Run feature

# %%
# Remove entire observation containing the outlier
for i in ToyotaCorolla_cont3['Run_KM']:
    Q1 = np.quantile(ToyotaCorolla_cont3.Run_KM,0.25)
    Q3 = np.quantile(ToyotaCorolla_cont3.Run_KM,0.75)
    IQR = Q3 - Q1
    upper_fence = Q3+(1.5*IQR)
    lower_fence = Q1-(1.5*IQR)
    if i > upper_fence or i < lower_fence:
        ToyotaCorolla_cont3.drop(ToyotaCorolla_cont3[ToyotaCorolla_cont3['Run_KM']==i].index,inplace=True)
ToyotaCorolla_cont3.shape
# Out:
# (1225, 4)

# %%
# Check for Outlier
plt.boxplot(ToyotaCorolla_cont3['Run_KM'])
plt.show()

# %% [markdown]
# #### Weight feature

# %%
# Remove entire observation containing the outlier
for i in ToyotaCorolla_cont3['Wt_Kgs']:
    Q1 = np.quantile(ToyotaCorolla_cont3.Wt_Kgs,0.25)
    Q3 = np.quantile(ToyotaCorolla_cont3.Wt_Kgs,0.75)
    IQR = Q3 - Q1
    upper_fence = Q3+(1.5*IQR)
    lower_fence = Q1-(1.5*IQR)
    if i > upper_fence or i < lower_fence:
        ToyotaCorolla_cont3.drop(ToyotaCorolla_cont3[ToyotaCorolla_cont3['Wt_Kgs']==i].index,inplace=True)
ToyotaCorolla_cont3.shape
# Out:
# (1190, 4)

# %%
# Check for Outlier
plt.boxplot(ToyotaCorolla_cont3['Wt_Kgs'])
plt.show()

# %% [markdown]
# # Step -6] Apply Transformations to the model

# %% [markdown]
# # Step -6.1] Model after applying Mean imputation method

# %%
model_1 = smf.ols("Price~Age_mns+Run_KM+Wt_Kgs",data=ToyotaCorolla_cont1).fit()

# %%
pred_1 = model_1.predict(ToyotaCorolla_cont1)
pred_1
# Out:
# 0       11681.323118
# 1       11538.662568
# 2       11653.198272
# 3       11504.379470
# 4       11328.716376
#             ...
# 1430     9254.371308
# 1431     9103.195347
# 1432     9171.225126
# 1433     9228.897984
# 1434     8863.260860
# Length: 1435, dtype: float64

# %%
# Overall Summary
model_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.388
# Model:                            OLS   Adj. R-squared:                  0.387
# Method:                 Least Squares   F-statistic:                     302.4
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):          5.18e-152
# Time:                        15:34:35   Log-Likelihood:                -12440.
# No. Observations:                1435   AIC:                         2.489e+04
# Df Residuals:                    1431   BIC:                         2.491e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.451e+04   1385.095     10.475      0.000    1.18e+04    1.72e+04
# ...

# %%
# Root Mean Square Error(RMSE)
rmse_1 = np.sqrt(model_1.mse_resid)
rmse_1
# Out:
# 1410.0019666187677

# %% [markdown]
# #### The R² value is decreased and the RMSE value increased.
# #### Apply all other transformations and select the model with best R² value and low RMSE.

# %% [markdown]
# # Step -6.2] Model after applying Median imputation method

# %%
model_2 = smf.ols("Price~Age_mns+Run_KM+Wt_Kgs",data = ToyotaCorolla_cont2).fit()

# %%
pred_2 = model_2.predict(ToyotaCorolla_cont2)
pred_2
# Out:
# 0       11524.234368
# 1       11394.421329
# 2       11496.756078
# 3       11357.566839
# 4       11189.627737
#             ...
# 1430     9262.281070
# 1431     9126.980722
# 1432     9190.770246
# 1433     9245.135557
# 1434     8822.700410
# Length: 1435, dtype: float64

# %%
# Overall Summary
model_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.342
# Model:                            OLS   Adj. R-squared:                  0.341
# Method:                 Least Squares   F-statistic:                     248.0
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):          1.46e-129
# Time:                        15:34:35   Log-Likelihood:                -12482.
# No. Observations:                1435   AIC:                         2.497e+04
# Df Residuals:                    1431   BIC:                         2.499e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.499e+04   1424.366     10.521      0.000    1.22e+04    1.78e+04
# ...

# %%
# Root Mean Square Error(RMSE)
rmse_2 = np.sqrt(model_2.mse_resid)
rmse_2
# Out:
# 1452.481153014752

# %% [markdown]
# # Step -6.3] Model after removing outlier

# %%
model_3 = smf.ols("Price~Age_mns+Run_KM+Wt_Kgs",data = ToyotaCorolla_cont3).fit()

# %%
pred_3 = model_3.predict(ToyotaCorolla_cont3)
pred_3
# Out:
# 9       14025.041525
# 27      14124.027861
# 30      14427.183670
# 31      14682.051409
# 33      14329.296252
#             ...
# 1430     9375.805970
# 1431     8984.567853
# 1432     9117.685303
# 1433     9218.380806
# 1434    10112.388566
# Length: 1190, dtype: float64

# %%
# Overall Summary
model_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.725
# Model:                            OLS   Adj. R-squared:                  0.724
# Method:                 Least Squares   F-statistic:                     1041.
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):               0.00
# Time:                        15:34:35   Log-Likelihood:                -9951.2
# No. Observations:                1190   AIC:                         1.991e+04
# Df Residuals:                    1186   BIC:                         1.993e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4167.8648   1193.059      3.493      0.000    1827.123    6508.607
# ...

# %%
# Root Mean Square Error(RMSE)
rmse_3 = np.sqrt(model_3.mse_resid)
rmse_3
# Out:
# 1038.0259523718778

# %% [markdown]
# #### Out of all the transformations, the model after removing the outlier has the best R² value and less RMSE value.
# #### But this model performance is poor than the Raw data model.

# %% [markdown]
# # Step -7] Check the significance of each indpendent variable

# %% [markdown]
# #### Perform Simple linear regression on each variable and check the significance. If the P-value<0.05, then it is significant.

# %% [markdown]
# #### Check for Significance of Age feature

# %%
Slr_Age = smf.ols("Price~Age_mns",data = ToyotaCorolla_cont).fit()

# %%
Slr_Age.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.768
# Method:                 Least Squares   F-statistic:                     4740.
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):               0.00
# Time:                        15:34:35   Log-Likelihood:                -12742.
# No. Observations:                1435   AIC:                         2.549e+04
# Df Residuals:                    1433   BIC:                         2.550e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.026e+04    145.926    138.818      0.000       2e+04    2.05e+04
# ...

# %% [markdown]
# #### As the P-value<0.05, Age feature is significant  to the model.

# %% [markdown]
# #### Check for Significance of Run feature

# %%
Slr_Run = smf.ols("Price~Run_KM",data = ToyotaCorolla_cont).fit()

# %%
Slr_Run.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.324
# Model:                            OLS   Adj. R-squared:                  0.324
# Method:                 Least Squares   F-statistic:                     687.6
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):          4.12e-124
# Time:                        15:34:35   Log-Likelihood:                -13509.
# No. Observations:                1435   AIC:                         2.702e+04
# Df Residuals:                    1433   BIC:                         2.703e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.448e+04    163.344     88.643      0.000    1.42e+04    1.48e+04
# ...

# %% [markdown]
# #### As the P-value<0.05, Run feature is insignificant  to the model.

# %% [markdown]
# #### Check for Significance of  Weight feature

# %%
Slr_Wt = smf.ols("Price~Wt_Kgs",data = ToyotaCorolla_cont).fit()

# %%
Slr_Wt.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.332
# Model:                            OLS   Adj. R-squared:                  0.331
# Method:                 Least Squares   F-statistic:                     711.0
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):          1.55e-127
# Time:                        15:34:35   Log-Likelihood:                -13501.
# No. Observations:                1435   AIC:                         2.701e+04
# Df Residuals:                    1433   BIC:                         2.702e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -3.193e+04   1601.273    -19.938      0.000   -3.51e+04   -2.88e+04
# ...

# %% [markdown]
# #### As the P-value<0.05, Weight feature significant  to the model.

# %% [markdown]
# #### The features are independently significant.
# #### Let us see whether they are combinedly showing the same.

# %% [markdown]
# #### Combination of features

# %%
arw_pr = smf.ols("Price~Age_mns+Run_KM+Wt_Kgs",data = ToyotaCorolla_cont).fit()

# %%
arw_pr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.847
# Model:                            OLS   Adj. R-squared:                  0.846
# Method:                 Least Squares   F-statistic:                     2635.
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):               0.00
# Time:                        15:34:35   Log-Likelihood:                -12444.
# No. Observations:                1435   AIC:                         2.490e+04
# Df Residuals:                    1431   BIC:                         2.492e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1722.7095    967.073     -1.781      0.075   -3619.743     174.324
# ...

# %%
# Root Mean Square Error(RMSE)
rmse_arw_pr = np.sqrt(arw_pr.mse_resid)
rmse_arw_pr
# Out:
# 1414.242733320169

# %% [markdown]
# #### The above model is showing good R² value and both the variables are significant to the model, as the P-values are <0.05. However check for multicollinearity by calculating Variance Inflation factor.

# %% [markdown]
# # Step -8] Calculate Variance Inflation Factor

# %%
rsq_a = smf.ols('Age_mns~Run_KM+Wt_Kgs',data = ToyotaCorolla_cont).fit().rsquared
vif_a = 1/(1-rsq_a)
vif_a
# Out:
# 1.8559235693401308

# %%
rsq_r = smf.ols('Run_KM~Age_mns+Wt_Kgs',data = ToyotaCorolla_cont).fit().rsquared
vif_r = 1/(1-rsq_r)
vif_r
# Out:
# 1.4528951340124632

# %%
rsq_w = smf.ols('Wt_Kgs~Age_mns+Run_KM',data = ToyotaCorolla_cont).fit().rsquared
vif_w = 1/(1-rsq_w)
vif_w
# Out:
# 1.3842090344564497

# %% [markdown]
# #### We have to remove the variable which is having the highest Variance Inflation factor(VIF). But here all the variables are having almost same VIF value.
# #### So, Build models eliminating one variable in each model.

# %%
Age_Run = smf.ols("Price~Age_mns+Run_KM",data = ToyotaCorolla_cont).fit()

# %%
Age_Run.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.790
# Model:                            OLS   Adj. R-squared:                  0.789
# Method:                 Least Squares   F-statistic:                     2687.
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):               0.00
# Time:                        15:34:36   Log-Likelihood:                -12672.
# No. Observations:                1435   AIC:                         2.535e+04
# Df Residuals:                    1432   BIC:                         2.536e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.045e+04    139.846    146.207      0.000    2.02e+04    2.07e+04
# ...

# %%
# Root Mean Square Error(RMSE)
rmse_Age_Run = np.sqrt(Age_Run.mse_resid)
rmse_Age_Run
# Out:
# 1656.511969578661

# %%
Run_Wt = smf.ols("Price~Run_KM+Wt_Kgs",data = ToyotaCorolla_cont).fit()

# %%
Run_Wt.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.641
# Model:                            OLS   Adj. R-squared:                  0.640
# Method:                 Least Squares   F-statistic:                     1276.
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):          7.40e-319
# Time:                        15:34:36   Log-Likelihood:                -13056.
# No. Observations:                1435   AIC:                         2.612e+04
# Df Residuals:                    1432   BIC:                         2.613e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2.727e+04   1182.234    -23.066      0.000   -2.96e+04    -2.5e+04
# ...

# %%
# Root Mean Square Error(RMSE)
rmse_Run_Wt = np.sqrt(Run_Wt.mse_resid)
rmse_Run_Wt
# Out:
# 2165.2070770547894

# %%
Wt_Age = smf.ols("Price~Wt_Kgs+Age_mns",data = ToyotaCorolla_cont).fit()

# %%
Wt_Age.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.804
# Model:                            OLS   Adj. R-squared:                  0.803
# Method:                 Least Squares   F-statistic:                     2929.
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):               0.00
# Time:                        15:34:36   Log-Likelihood:                -12622.
# No. Observations:                1435   AIC:                         2.525e+04
# Df Residuals:                    1432   BIC:                         2.527e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3356.0245   1056.440      3.177      0.002    1283.689    5428.360
# ...

# %%
# Root Mean Square Error(RMSE)
rmse_Wt_Age = np.sqrt(Wt_Age.mse_resid)
rmse_Wt_Age
# Out:
# 1600.6272826537736

# %% [markdown]
# # Step -9] Final Results

# %%
results = {"MODEL":pd.Series(["Raw data","Mean Imputation model","Median Imputation model","After removing outlier","Comb. of Age and Run","Comb. of Run and Weight","Comb. of Weight and Age"]),
           "R²_Values":pd.Series([model.rsquared,model_1.rsquared,model_2.rsquared,model_3.rsquared,Age_Run.rsquared,Run_Wt.rsquared,Wt_Age.rsquared]),
           "RMSE_Values":pd.Series([rmse,rmse_1,rmse_2,rmse_3,rmse_Age_Run,rmse_Run_Wt,rmse_Wt_Age])
          }
result_table=pd.DataFrame(results)
result_table
# Out:
#                      MODEL  R²_Values  RMSE_Values
# 0                 Raw data   0.846740  1414.242733
# 1    Mean Imputation model   0.387962  1410.001967
# 2  Median Imputation model   0.342050  1452.481153
# 3   After removing outlier   0.724773  1038.025952
# 4     Comb. of Age and Run   0.789587  1656.511970
# 5  Comb. of Run and Weight   0.640513  2165.207077
# 6  Comb. of Weight and Age   0.803544  1600.627283

# %%
sb.barplot(x=result_table['R²_Values'],y=result_table['MODEL'])
plt.title("R-squared values for different models")
plt.show()

# %%
sb.barplot(x=result_table['RMSE_Values'],y=result_table['MODEL'])
plt.title("RMSE values for different models")
plt.show()

# %% [markdown]
# #### From the above results, we can see that the model using Raw data gives the best R² value and less RMSE value
# #### Hence this model can be selected as our final model and used for predicting the price.

# %% [markdown]
# # Step -10] Residual Analysis

# %% [markdown]
# #### Q-Q Plot

# %%
#Residuals values or errors
sm.qqplot(model.resid, line = 'q')
plt.title('Normal Q-Q plot of residuals')
plt.show()

# %% [markdown]
# #### Test for Homoscedasticity

# %%
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()

# %%
plt.scatter(get_standardized_values(model.fittedvalues), model.resid_pearson)
plt.title('Residual Plot')
plt.xlabel('Standardized Fitted Values')
plt.ylabel('Standardized Residual Values')
plt.show()

# %%
plt.plot(np.arange(len(ToyotaCorolla_cont)),model.resid_pearson)
plt.axhline(y=0,color='yellow')
plt.xlabel("Observation Number")
plt.ylabel("Standardized Residual")
plt.show()

# %%
plt.scatter(np.arange(len(ToyotaCorolla_cont)),model.resid_pearson)
plt.axhline(y=0,color='yellow')
plt.xlabel("Observation Number")
plt.ylabel("Standardized Residual")
plt.show()

# %%
plt.hist(model.resid_pearson)
plt.show()

# %% [markdown]
# #### Residual VS Regressors

# %%
fig = plt.figure(figsize = (16,9))
plot_Age = sm.graphics.plot_regress_exog(model, 'Age_mns', fig=fig)
plt.show()

# %%
fig = plt.figure(figsize = (16,9))
plot_Run = sm.graphics.plot_regress_exog(model, 'Run_KM', fig=fig)
plt.show()

# %%
fig = plt.figure(figsize = (16,9))
plot_Weight = sm.graphics.plot_regress_exog(model, 'Wt_Kgs', fig=fig)
plt.show()

# %% [markdown]
# # Step -11] Detecting Influencers in the Model

# %% [markdown]
# #### By using Cook's distance

# %%
influence_points=model.get_influence()
c, p_value=influence_points.cooks_distance

# %%
# Leverage Value using High Influence Points : Points beyond Leverage_cutoff value are influencers
fig,ax=plt.subplots(figsize=(20,20))
fig=influence_plot(model,ax = ax)
plt.show()

# %% [markdown]
# #### Leverage Cuttoff Value = 3*(k+1)/n ; k = no.of features/columns & n = no. of datapoints

# %%
k=ToyotaCorolla_cont.shape[1]
n=ToyotaCorolla_cont.shape[0]
leverage_cutoff = (3*(k+1))/n
print('Cut-off line at',np.round(leverage_cutoff,2))
# Out:
# Cut-off line at 0.01

# %% [markdown]
# #### Let's plot the influencers and also plot a cut off line using the stem plot

# %%
fig = plt.figure(figsize = (16,9))
x = [0,1435]
y = [0.1,0.1]
plt.plot(x, y,color='darkred', linewidth=2)
y1 = [0.01,0.01]
plt.plot(x , y1, color = 'red', linewidth = 2)
plt.stem(np.arange(len(ToyotaCorolla_cont)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel("Cook's Distance")
plt.show()

# %%
# Index and value of influencer where C>0.5
np.argmax(c) , np.max(c)
# Out:
# (220, 1.5183498455717954)

# %%
ToyotaCorolla_cont[ToyotaCorolla_cont.index.isin([220])]
# Out:
#      Price  Age_mns  Run_KM  Wt_Kgs
# 220  12450       44   74172    1615

# %% [markdown]
# #### Let's improve the model by deleting the influence point and creating a new dataframe

# %%
ToyotaCorolla_f= ToyotaCorolla_cont.copy()
# Discard the data points which are influencers and reassign the row number (reset_index(drop=True))
ToyotaCorolla_f = ToyotaCorolla_f.drop(ToyotaCorolla_f.index[[220]],axis=0).reset_index(drop=True)
ToyotaCorolla_f.shape
# Out:
# (1434, 4)

# %% [markdown]
# # Step -12] Model Deletion Diagnostics and Final Model

# %%
while model.rsquared < 0.90:
    for c in [np.max(c)>leverage_cutoff]:
        model=smf.ols('Price~Age_mns+Run_KM+Wt_Kgs',data = ToyotaCorolla_f).fit()
        (c,_)=model.get_influence().cooks_distance
        c
        np.argmax(c) , np.max(c)
        ToyotaCorolla_f = ToyotaCorolla_f.drop(ToyotaCorolla_f.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
        ToyotaCorolla_f
    else:
        model_f = smf.ols('Price~Age_mns+Run_KM+Wt_Kgs',data = ToyotaCorolla_f).fit()
        model_f.rsquared , model_f.aic
        print("Thus model accuracy is improved to",model_f.rsquared)
# Out:
# Thus model accuracy is improved to 0.8578485217349112
# Thus model accuracy is improved to 0.863277046409452
# Thus model accuracy is improved to 0.8607898879814079
# Thus model accuracy is improved to 0.8581582611566132
# Thus model accuracy is improved to 0.855494180721075
# Thus model accuracy is improved to 0.8573270219543845
# Thus model accuracy is improved to 0.8593111598478697
# Thus model accuracy is improved to 0.860225645330987
# Thus model accuracy is improved to 0.8624893340871542
# Thus model accuracy is improved to 0.8631949394421121
# Thus model accuracy is improved to 0.863898229527887
# Thus model accuracy is improved to 0.864693167477483
# Thus model accuracy is improved to 0.8655914622411143
# Thus model accuracy is improved to 0.8659064994817832
# Thus model accuracy is improved to 0.8662670534586867
# Thus model accuracy is improved to 0.8650450242099621
# Thus model accuracy is improved to 0.8652057341292722
# ...

# %%
influence_points=model_f.get_influence()
c, p_value=influence_points.cooks_distance

# %%
ToyotaCorolla_f.shape
# Out:
# (910, 4)

# %%
ToyotaCorolla_f.head()
# Out:
#    Price  Age_mns  Run_KM  Wt_Kgs
# 0  14950       26   32692    1100
# 1  15500       22   41000    1100
# 2  14950       23   10000    1100
# 3  14750       27   27500    1100
# 4  15500       25   49163    1165

# %%
fig = plt.figure(figsize = (16,9))
x = [0,910]
y = [0.5,0.5]
plt.plot(x, y,color='darkred', linewidth=2)
y1 = [0.01,0.01]
plt.plot(x , y1, color = 'red', linewidth = 2)
plt.stem(np.arange(len(ToyotaCorolla_f)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel("Cook's Distance")
plt.show()

# %% [markdown]
# #### Hence, we can see that there are no influncers present in our model.

# %%
# Overall Summary
model_f.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.900
# Model:                            OLS   Adj. R-squared:                  0.900
# Method:                 Least Squares   F-statistic:                     2730.
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):               0.00
# Time:                        15:34:57   Log-Likelihood:                -7101.9
# No. Observations:                 910   AIC:                         1.421e+04
# Df Residuals:                     906   BIC:                         1.423e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -112.5585    829.245     -0.136      0.892   -1740.023    1514.906
# ...

# %%
# Root Mean Square Error(RMSE)
rmse_f = np.sqrt(model_f.mse_resid)
rmse_f
# Out:
# 594.4022234686771

# %% [markdown]
# #### From the above results, we can see that this model gives the best R² value and less RMSE value
# #### Hence this model can be selected as our final model and used for predicting the price.

# %% [markdown]
# # Step -13] Using the model for new data

# %%
#Predict for new data
newdata={'Age_mns':[10,20,30],'Run_KM':[10000,20000,10000],'Wt_Kgs':[1000,1500,2000]}

# %%
data_pred=pd.DataFrame(newdata,columns=['Age_mns','Run_KM','Wt_Kgs'])
data_pred
# Out:
#    Age_mns  Run_KM  Wt_Kgs
# 0       10   10000    1000
# 1       20   20000    1500
# 2       30   10000    2000

# %%
new_pred = model_f.predict(data_pred)
data_pred['Pred_Price']=np.round(new_pred,2)
data_pred
# Out:
#    Age_mns  Run_KM  Wt_Kgs  Pred_Price
# 0       10   10000    1000    14931.47
# 1       20   20000    1500    21863.67
# 2       30   10000    2000    29016.40

# %% [markdown]
# #### Hence the Multiple Linear Regression model gives accurate predictions.
